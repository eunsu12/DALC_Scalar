# %% [markdown]
# <a href="https://colab.research.google.com/github/eunsu12/DALC_Scalar/blob/main/K_MOOC_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 빅데이터 시각화(matplotlib)
# ### 그래프 생성
# ### 두 종류의 인터페이스 ->  MATLAB 스타일 / 객체 지향 스타일(어떻게 처음 상태를 수정할 수 있을까?, 그림 복잡)
# ### 선그림

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
fig.suptitle('Example 1:line Plot')
ax = plt.axes()

# %% [markdown]
# ###plt.plot(x,np.cos(x*2))
# ###plt.axis([-1,11,-1.5,1.5]); 축의 범위 지정
# ###스케일 변경 plt.yscale('log')
# ###축의 레이블 추가 plt.ylabel() plt.xlabel()
# ###범례 추가 plt.legend()

# %%
x = np.linspace(0,10,25)
plt.plot(x,np.sin(x),'-og')

# %% [markdown]
# ###다중 서브 플롯

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4,wspace=0.4)
nrows,ncols=3,4
for i in range(nrows*ncols):
  plt.subplot(nrows,ncols,i+1)
  plt.text(0.5,0.5,str((nrows,ncols,i+1)), fontsize=16,ha='center')
